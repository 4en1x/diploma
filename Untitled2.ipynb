# %% [markdown]
# <a href="https://colab.research.google.com/github/4en1x/diploma/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt update -qq;
# !wget https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb;
# !dpkg -i cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb;
# !apt-key add /var/cuda-repo-8-0-local-ga2/7fa2af80.pub;
# !apt-get update -qq;
# !apt-get install gcc-4.8 g++-4.8 -y -qq;
# !ln -s /usr/bin/gcc-4.8 /usr/local/cuda/bin/gcc;
# !ln -s /usr/bin/g++-4.8 /usr/local/cuda/bin/g++;
# !apt install cuda-8.0;
# !update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-4.8 60 --slave /usr/bin/g++ g++ /usr/bin/g++-4.8
# Out:
# 111 packages can be upgraded. Run 'apt list --upgradable' to see them.
# --2019-03-22 07:36:32--  https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# Resolving developer.nvidia.com (developer.nvidia.com)... 192.229.162.216
# Connecting to developer.nvidia.com (developer.nvidia.com)|192.229.162.216|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://developer.download.nvidia.com/compute/cuda/8.0/secure/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64.deb?4Urc7DNmwFQnzivkWYDCwQP1Z3RegeUKGHK4BIVD3oHAjXHagMXxqHxMrqO5uJHAdbEjSMQcCGI0o35JJhoZ0VLJmxplATKkEEvw8hDHMj7RgrIfzr1nb58UgBk0c6Jnt1XEWRcrWNMOXELVkP3oWcGaNPwbxcAciyGGD2CkxKKHi1ZwJfLVGz7z5D0J11C6h1b-ExKspri_Pa5hcfoWnP71DA [following]
# ...

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2016 NVIDIA Corporation
# Built on Tue_Jan_10_13:22:03_CST_2017
# Cuda compilation tools, release 8.0, V8.0.61

# %%
# !pip install git+git://github.com/andreinechaev/nvcc4jupyter.git
# Out:
# ...
#   Cloning git://github.com/andreinechaev/nvcc4jupyter.git to /tmp/pip-req-build-6dxcstkg
# ...
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wbty008a/wheels/10/c2/05/ca241da37bff77d60d31a9174f988109c61ba989e4d4650516
# Successfully built NVCCPlugin
# ...

# %%
# %load_ext nvcc_plugin
# Out:
# created output directory at /content/src
# Out bin /content/result.out

# %%
# !cd /usr/src
# !ln -sfn linux-headers-2.6.35-28-generic linux

# %%
# %%cu
# #include <cuda_runtime.h>
# #include "device_launch_parameters.h"
# #include <stdlib.h>
# #include <stdio.h>
# #include "linux/kernel.h"
# #include <iostream>
# #include <ctime>
# #include <iomanip>
# #include <fstream>
# #include <math.h>
# #include <cmath>
#
# using namespace std;
#
# #define ITERATIONS 1000000
# #define N 256
#
# #define e 2.7182818
#
# #define blockZSize 1
#
# #define blockXSize 32
# #define blockYSize 32
#
# #define tileXSize 8
# #define tileYSize 8
#
# #define extN (N + 2 * blockZSize)
# #define Dx 1
# #define h ((double) Dx / (N + 1))
# #define h2 powf(h, 2.0)
#
# __device__
# double f(int i, int j) {
# 	return 2 * powf(e, i * h + j * h);
# }
#
# double u_t(double x) {
# 	return powf(e, x);
# }
#
# double u_l(double x) {
# 	return powf(e, x);
# }
#
# double u_r(double x) {
# 	return powf(e, x + 1);
# }
#
# double u_d(double x) {
# 	return powf(e, x + 1);
# }
#
#
# __device__
# void tile(double* matrix, int iGl, int jGl, bool isBlack) {
# 	int iBegin = iGl * blockXSize + threadIdx.x * tileXSize + blockZSize;
# 	int jBegin = jGl * blockYSize + threadIdx.y * tileYSize + blockZSize;
#
#   int N1 = tileXSize + blockZSize * 2;
#   int N2 = tileYSize + blockZSize * 2;
#
# 	double helper[8 * 10 * 10];
#
#   for(int i = 0; i < N1; i++) {
# 		for(int j = 0; j < N2; j++) {
# 			helper[i * N1 + j] = matrix[extN * (iBegin - blockZSize + i) + jBegin - blockZSize + j];
# 		}
# 	}
#
#   for(int k = 1; k < blockZSize; k++) {
# 		for (int i = k; i < N1 - k; i++) {
# 		  int offset = (i + k - blockZSize) % 2;
# 		  if (isBlack) {
# 			  offset = 1 - offset;
# 		  }
# 		  for (int j = k + offset; j < N2 - k; j += 2) {
# 			  helper[N1 * i + j] = 0.25 * (
#             helper[N1 * (i + 1) + j]
#           + helper[N1 * (i - 1) + j]
#           + helper[N1 * i + j + 1]
# 				  + helper[N1 * i + j - 1]
#           - h2 * f(iBegin - 2 * blockZSize + i + 1, jBegin - 2 * blockZSize + j + 1)
#         );
# 		  }
# 	  }
# 	}
#
#   //printf("iGl : %d, %d, %d, %d, %d, %d, %d \n", iGl, jGl, threadIdx.x, threadIdx.y, isBlack, iBegin, jBegin);
#
# 	for (int i = iBegin; i < iBegin + tileXSize; i++) {
# 		int offset = i % 2;
# 		if (isBlack) {
# 			offset = 1 - offset;
# 		}
# 		for (int j = jBegin + offset; j < jBegin + tileYSize; j += 2) {
#       int helperIIndex = i - iBegin + blockZSize;
#       int helperJIndex = j - jBegin + blockZSize;
# 			matrix[extN * i + j] = 0.25 * (
#           helper[N1 * (helperIIndex + 1) + helperJIndex]
#         + helper[N1 * (helperIIndex - 1) + helperJIndex]
#         + helper[N1 * helperIIndex + helperJIndex + 1]
# 				+ helper[N1 * helperIIndex + helperJIndex - 1]
#         - h2 * f(i - blockZSize + 1, j - blockZSize + 1)
#       );
# 		}
# 	}
#
# }
#
# __global__
# void calculateBlack(double* matrix) {
# 	tile(matrix, blockIdx.x, blockIdx.y, true);
# }
#
# __global__
# void calculateRed(double* matrix) {
# 	tile(matrix, blockIdx.x, blockIdx.y, false);
# }
#
# double func(int i, int j) {
# 	return powf(e, i * h + j * h);
# }
#
# double* createMatrix(int row, int col) {
# 	double* matrix = new double[row * col];
#
# 	for(int i = 0; i < row; i++) {
# 		for(int j = 0; j < col; j++) {
# 			matrix[i * row + j] = 0;
# 		}
# 	}
#
#   for(int k = 0; k < blockZSize; k++) {
#     for(int i = k; i < row - k; i++) {
#       matrix[k * row + i] = u_t((i - blockZSize + 1) * h);
#       matrix[(row - 1 - k) * row + i] = u_d((i - blockZSize + 1) * h);
#     }
# 	}
#
#   for(int k = 0; k < blockZSize; k++) {
#     for(int j = k; j < col - k; j++) {
#       matrix[j * col + k] = u_l((j - blockZSize + 1) * h);
#       matrix[j * col + row - 1 - k] = u_r((j - blockZSize + 1) * h);
# 	  }
#   }
#
# 	return matrix;
# }
#
# double calculateDifference(double* matrix1) {
# 	double tolerance = 0.0f;
#
#   for (int i = blockZSize; i < extN - blockZSize; i++) {
# 		for (int j = blockZSize; j < extN - blockZSize; j++) {
#       double fCurrent = func(i - blockZSize + 1, j - blockZSize + 1);
#       if(abs(matrix1[i * extN + j] - fCurrent) > tolerance) {
#           tolerance = abs(matrix1[i * extN + j] - fCurrent);
#       }
# 		}
# 	}
#
# 	return tolerance;
# }
#
# int main() {
#   ofstream myfile;
#   myfile.open("example.txt");
# 	double* matrixHost = createMatrix(extN, extN);
#
# /*
#   for (size_t i = 0; i < extN; i++) {
# 		for (size_t j = 0; j < extN; j++) {
#       myfile << matrixHost[i * extN + j] << " ";
# 		}
#     myfile << "\n";
# 	}
# */
#
#
# 	double* matrixDevice;
#
# 	int matrixSize = sizeof(double) * extN * extN;
#
# 	cudaMalloc((void**)&matrixDevice, matrixSize);
# 	cudaMemcpy(matrixDevice, matrixHost, matrixSize, cudaMemcpyHostToDevice);
#
# 	long startTime = clock();
# 	dim3 blocks(N / blockXSize, N / blockYSize);
# 	dim3 threads(blockXSize / tileXSize, blockYSize / tileYSize);
#
# 	for (size_t i = 0; i < ITERATIONS; i++) {
# 		calculateBlack <<< blocks, threads >>>(matrixDevice);
# 		cudaDeviceSynchronize();
# 		calculateRed <<< blocks, threads >>>(matrixDevice);
#
# 		cudaPeekAtLastError();
# 		cudaDeviceSynchronize();
#
#     cudaMemcpy(matrixHost, matrixDevice, matrixSize, cudaMemcpyDeviceToHost);
#
#     if(i%100 == 0) {
#         double diff = calculateDifference(matrixHost);
#         cout << " Difference: " << diff;
#         if(diff < 0.0001) break;
#     }
#
# /*
#     for (size_t i = 0; i < extN; i++) {
# 		  for (size_t j = 0; j < extN; j++) {
#         myfile << matrixHost[i * extN + j] << " ";
# 		  }
#       myfile << "\n";
# 	 }
# */
# 	}
#
# 	std::cout << "Calculation take time: " << clock() - startTime << std::endl;
#   cout << " Difference: " << calculateDifference(matrixHost);
# 	cudaError_t cudaResult = cudaMemcpy(matrixHost, matrixDevice, matrixSize, cudaMemcpyDeviceToHost);
#
# 	if (cudaResult != cudaSuccess) {
# 		std::cout << "Cuda error: " << cudaResult << std::endl;
# 	}
#   myfile.close();
# 	return 0;
# }
# Out:
# ' Difference: 7.275 Difference: 5.92325 Difference: 5.47826 Difference: 5.17354 Difference: 4.93636 Difference: 4.74083 Difference: 4.57367 Difference: 4.42734 Difference: 4.2971 Difference: 4.17991 Difference: 4.07324 Difference: 3.97505 Difference: 3.8845 Difference: 3.8001 Difference: 3.7213 Difference: 3.64748 Difference: 3.5779 Difference: 3.51212 Difference: 3.4498 Difference: 3.39063 Difference: 3.33416 Difference: 3.28006 Difference: 3.22834 Difference: 3.17854 Difference: 3.13057 Difference: 3.08415 Difference: 3.03927 Difference: 2.99558 Difference: 2.95302 Difference: 2.9116 Difference: 2.87105 Difference: 2.83132 Difference: 2.79232 Difference: 2.75398 Difference: 2.71626 Difference: 2.67908 Difference: 2.6424 Difference: 2.60624 Difference: 2.57058 Difference: 2.53531 Difference: 2.50038 Difference: 2.46597 Difference: 2.43189 Difference: 2.39813 Difference: 2.36485 Difference: 2.3318 Difference: 2.29927 Difference: 2.26694 Difference: 2.23512 Difference: 2.20352 Differe
# ...
